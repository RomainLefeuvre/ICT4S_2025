# %%
import pandas as pd
import sys
import importlib
sys.path.append("../scripts/")
import regex_gradle
import rq_aux
import re
import matplotlib.pyplot as plt 
import seaborn as sns

importlib.reload(regex_gradle)
importlib.reload(rq_aux)
 #"small", "medium", "large"
sizes1 = rq_aux.sizes1

#"all", "small", "medium", "large"
sizes2 = rq_aux.sizes2

# %%
regex = regex_gradle
plugins = regex.plugins
categories = regex.categories
categories_short = regex.categories_short
prefix = "gradle_"
build_tool = "gradle"
is_build_tool = "is_gradle"
noerror = True
output_path = "../data/output_data/"
overview_dataset = f"{output_path}overview_daylight_noerror.csv"
alltasks_dataset = f"{output_path}all_tasks_noerror.csv"

# %%
rq_aux.check_categories(regex)

# %%
df = rq_aux.read_all_tasks(alltasks_dataset, build_tool, noerror)
# Out:
# Tasks With Error: Removed 0 workflows: 181203 -> 181203
# Build tool gradle = 45259

# %%
tasks = {}
for x in sizes1:
  tasks[x] = rq_aux.get_tasks_by_kind(df[df["size"] == x], plugins)

tasks['all'] = rq_aux.get_tasks_by_kind(df, plugins)

# %%
sum_tasks = {}
for x in sizes2:
  sum_tasks[x] = rq_aux.calc_energy_by_task(tasks[x])

# %%
for x in sizes2:
  print(f"**** {x.title()} ****")
  rq_aux.print_all_tasks(rq_aux.filter_tasks_by(sum_tasks[x], '', 0.02))
  print("")
# Out:
# **** All ****
# total: Energy: 6221774.754941069 (100.0%)
# test: Energy: 1794550.8904868066 (28.8%)
# jmh: Energy: 666912.250396649 (10.7%)
# other: Energy: 622871.8667808997 (10.0%)
# javadoc: Energy: 284742.5509916971 (4.6%)
# publish: Energy: 261143.7622737582 (4.2%)
# func_test: Energy: 243159.86741640556 (3.9%)
# build: Energy: 225309.68129275588 (3.6%)
# compile: Energy: 198044.85424105797 (3.2%)
# jar: Energy: 197491.55279831475 (3.2%)
# build_src: Energy: 177420.7789023028 (2.9%)
# checkstyle: Energy: 167521.0895869761 (2.7%)
# test_class: Energy: 147419.94039543663 (2.4%)
#
# **** Small ****
# total: Energy: 162448.83453355863 (100.0%)
# plugin-verifier: Energy: 93421.4843739821 (57.5%)
# other: Energy: 23877.95570034474 (14.7%)
# test: Energy: 8279.375270276762 (5.1%)
# jar: Energy: 5478.76339982698 (3.4%)
# javadoc: Energy: 5100.688325883181 (3.1%)
# spotless: Energy: 4819.1230120089485 (3.0%)
# compile: Energy: 3370.117706301797 (2.1%)
# resources: Energy: 3285.275331639101 (2.0%)
#
# **** Medium ****
# total: Energy: 2066005.9607967474 (100.0%)
# test: Energy: 494370.6134068828 (23.9%)
# publish: Energy: 253396.32822974658 (12.3%)
# other: Energy: 223628.1215319182 (10.8%)
# func_test: Energy: 220513.28654447265 (10.7%)
# build: Energy: 106049.54473715457 (5.1%)
# compile: Energy: 82646.46594820512 (4.0%)
# checkstyle: Energy: 82113.70839899269 (4.0%)
# test_class: Energy: 76356.67693606268 (3.7%)
# jar: Energy: 65700.27050145243 (3.2%)
# build_src: Energy: 50511.27096261553 (2.4%)
# check: Energy: 49673.54341433848 (2.4%)
#
# **** Large ****
# total: Energy: 3993319.959610764 (100.0%)
# test: Energy: 1291900.9018096458 (32.4%)
# jmh: Energy: 655537.6326827313 (16.4%)
# other: Energy: 375365.7895486366 (9.4%)
# javadoc: Energy: 261636.45524847385 (6.6%)
# jar: Energy: 126312.51889703544 (3.2%)
# build_src: Energy: 125407.18865914785 (3.1%)
# build: Energy: 118034.35953096983 (3.0%)
# compile: Energy: 112028.27058655146 (2.8%)
# integ_test: Energy: 100131.55587452078 (2.5%)
# spotbugs: Energy: 96205.45904621316 (2.4%)
# classes: Energy: 85821.15101073563 (2.1%)
# checkstyle: Energy: 84009.39105371157 (2.1%)

# %%
df = pd.read_csv(overview_dataset)

# Remove Maven Workflows Without Maven Subtasks
df = rq_aux.remove_workflows_no_subtask(df[df[is_build_tool]], prefix, plugins)

df_size = rq_aux.create_dfs_size(df, is_build_tool)
# Out:
# Workflows No Subtask: Removed 302 workflows: 719 -> 417

# %%
# Calculate maven-related energy consumption for all maven projects
tasks = {}

for x in sizes2:
  print(f"*** {x.title()} ***")
  tasks[x] = rq_aux.calc_sum(df_size[x], prefix, plugins)
  rq_aux.calc_workflow_energy_proportion (df_size[x], tasks[x])
  rq_aux.calc_ratio(tasks[x])
  print(f"{df_size[x]['energy'].sum():0.2f}")
# Out:
# *** All ***
# Energy:  6221775 (28.1%)
# Seconds:  286877252134 (25.9%)
# 22112765.67
# *** Small ***
# Energy:  162449 (39.7%)
# Seconds:  7902238194 (36.2%)
# 408948.65
# *** Medium ***
# Energy:  2066006 (36.0%)
# Seconds:  93138667065 (33.3%)
# 5740522.07
# *** Large ***
# Energy:  3993320 (25.0%)
# Seconds:  185836346875 (23.0%)
# 15963294.94
# /home/rlefeuvr/Documents/Workspace/ICT4S_2025/energy-CI-CD/analysis/../scripts/rq_aux.py:46: RuntimeWarning: invalid value encountered in scalar divide
#   return round(100 * x / y, n)

# %%
for x in sizes2:
  print(f"**** {x.title()} ****")
  rq_aux.print_tasks_summary(rq_aux.filter_tasks_by(tasks[x], 'energy', 0.02))
  print("")
# Out:
# **** All ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Gradle_Test ***
# N:  4.7%;  Energy:  28.8%;  Seconds:  26.2%;  Rat_P:  nan%;  Rat_N:  612.3%;
# *** Gradle_Jmh ***
# N:  0.9%;  Energy:  10.7%;  Seconds:  15.4%;  Rat_P:  nan%;  Rat_N:  1163.4%;
# *** Gradle_Other ***
# N:  29.3%;  Energy:  10.0%;  Seconds:  9.8%;  Rat_P:  nan%;  Rat_N:  34.2%;
# *** Gradle_Javadoc ***
# N:  3.9%;  Energy:  4.6%;  Seconds:  3.8%;  Rat_P:  nan%;  Rat_N:  116.8%;
# *** Gradle_Publish ***
# N:  0.5%;  Energy:  4.2%;  Seconds:  3.4%;  Rat_P:  nan%;  Rat_N:  917.7%;
# *** Gradle_Func_Test ***
# N:  0.1%;  Energy:  3.9%;  Seconds:  4.1%;  Rat_P:  nan%;  Rat_N:  4314.2%;
# *** Gradle_Build ***
# N:  4.2%;  Energy:  3.6%;  Seconds:  3.9%;  Rat_P:  nan%;  Rat_N:  85.5%;
# *** Gradle_Compile ***
# N:  5.5%;  Energy:  3.2%;  Seconds:  2.8%;  Rat_P:  nan%;  Rat_N:  58.4%;
# *** Gradle_Jar ***
# N:  7.7%;  Energy:  3.2%;  Seconds:  3.0%;  Rat_P:  nan%;  Rat_N:  41.0%;
# *** Gradle_Build_Src ***
# N:  2.7%;  Energy:  2.9%;  Seconds:  2.7%;  Rat_P:  nan%;  Rat_N:  107.3%;
# *** Gradle_Checkstyle ***
# N:  3.9%;  Energy:  2.7%;  Seconds:  2.4%;  Rat_P:  nan%;  Rat_N:  68.7%;
# *** Gradle_Test_Class ***
# N:  5.2%;  Energy:  2.4%;  Seconds:  2.0%;  Rat_P:  nan%;  Rat_N:  45.9%;
#
# **** Small ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Gradle_Plugin-Verifier ***
# N:  0.8%;  Energy:  57.5%;  Seconds:  56.8%;  Rat_P:  nan%;  Rat_N:  7655.0%;
# *** Gradle_Other ***
# N:  41.8%;  Energy:  14.7%;  Seconds:  13.0%;  Rat_P:  nan%;  Rat_N:  35.1%;
# *** Gradle_Test ***
# N:  4.9%;  Energy:  5.1%;  Seconds:  7.6%;  Rat_P:  nan%;  Rat_N:  103.5%;
# *** Gradle_Jar ***
# N:  7.3%;  Energy:  3.4%;  Seconds:  3.6%;  Rat_P:  nan%;  Rat_N:  46.4%;
# *** Gradle_Javadoc ***
# N:  1.8%;  Energy:  3.1%;  Seconds:  3.6%;  Rat_P:  nan%;  Rat_N:  171.0%;
# *** Gradle_Spotless ***
# N:  6.2%;  Energy:  3.0%;  Seconds:  3.3%;  Rat_P:  nan%;  Rat_N:  48.0%;
# *** Gradle_Compile ***
# N:  3.0%;  Energy:  2.1%;  Seconds:  1.5%;  Rat_P:  nan%;  Rat_N:  69.0%;
# *** Gradle_Resources ***
# N:  2.4%;  Energy:  2.0%;  Seconds:  1.6%;  Rat_P:  nan%;  Rat_N:  83.5%;
#
# **** Medium ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Gradle_Test ***
# N:  5.4%;  Energy:  23.9%;  Seconds:  27.4%;  Rat_P:  nan%;  Rat_N:  445.9%;
# *** Gradle_Publish ***
# N:  0.3%;  Energy:  12.3%;  Seconds:  10.1%;  Rat_P:  nan%;  Rat_N:  4100.0%;
# *** Gradle_Other ***
# N:  17.5%;  Energy:  10.8%;  Seconds:  11.2%;  Rat_P:  nan%;  Rat_N:  61.7%;
# *** Gradle_Func_Test ***
# N:  0.2%;  Energy:  10.7%;  Seconds:  11.3%;  Rat_P:  nan%;  Rat_N:  4955.4%;
# *** Gradle_Build ***
# N:  5.3%;  Energy:  5.1%;  Seconds:  5.9%;  Rat_P:  nan%;  Rat_N:  96.5%;
# *** Gradle_Compile ***
# N:  5.3%;  Energy:  4.0%;  Seconds:  3.7%;  Rat_P:  nan%;  Rat_N:  75.7%;
# *** Gradle_Checkstyle ***
# N:  7.9%;  Energy:  4.0%;  Seconds:  3.0%;  Rat_P:  nan%;  Rat_N:  50.3%;
# *** Gradle_Test_Class ***
# N:  7.5%;  Energy:  3.7%;  Seconds:  3.4%;  Rat_P:  nan%;  Rat_N:  49.4%;
# *** Gradle_Jar ***
# N:  7.4%;  Energy:  3.2%;  Seconds:  2.9%;  Rat_P:  nan%;  Rat_N:  42.9%;
# *** Gradle_Build_Src ***
# N:  2.3%;  Energy:  2.4%;  Seconds:  2.4%;  Rat_P:  nan%;  Rat_N:  107.5%;
# *** Gradle_Check ***
# N:  1.8%;  Energy:  2.4%;  Seconds:  2.6%;  Rat_P:  nan%;  Rat_N:  130.9%;
#
# **** Large ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Gradle_Test ***
# N:  4.3%;  Energy:  32.4%;  Seconds:  26.4%;  Rat_P:  nan%;  Rat_N:  752.3%;
# *** Gradle_Jmh ***
# N:  1.4%;  Energy:  16.4%;  Seconds:  23.5%;  Rat_P:  nan%;  Rat_N:  1148.1%;
# *** Gradle_Other ***
# N:  35.9%;  Energy:  9.4%;  Seconds:  8.9%;  Rat_P:  nan%;  Rat_N:  26.1%;
# *** Gradle_Javadoc ***
# N:  3.8%;  Energy:  6.6%;  Seconds:  5.3%;  Rat_P:  nan%;  Rat_N:  174.6%;
# *** Gradle_Jar ***
# N:  8.0%;  Energy:  3.2%;  Seconds:  3.0%;  Rat_P:  nan%;  Rat_N:  39.7%;
# *** Gradle_Build_Src ***
# N:  3.0%;  Energy:  3.1%;  Seconds:  3.0%;  Rat_P:  nan%;  Rat_N:  105.2%;
# *** Gradle_Build ***
# N:  3.7%;  Energy:  3.0%;  Seconds:  3.0%;  Rat_P:  nan%;  Rat_N:  80.3%;
# *** Gradle_Compile ***
# N:  5.7%;  Energy:  2.8%;  Seconds:  2.5%;  Rat_P:  nan%;  Rat_N:  49.5%;
# *** Gradle_Integ_Test ***
# N:  0.3%;  Energy:  2.5%;  Seconds:  3.0%;  Rat_P:  nan%;  Rat_N:  770.5%;
# *** Gradle_Spotbugs ***
# N:  1.4%;  Energy:  2.4%;  Seconds:  1.8%;  Rat_P:  nan%;  Rat_N:  170.7%;
# *** Gradle_Classes ***
# N:  6.2%;  Energy:  2.1%;  Seconds:  1.9%;  Rat_P:  nan%;  Rat_N:  34.9%;
# *** Gradle_Checkstyle ***
# N:  1.5%;  Energy:  2.1%;  Seconds:  2.1%;  Rat_P:  nan%;  Rat_N:  137.0%;

# %%
energy_category = {}

for x in sizes2:
  energy_category[x] = rq_aux.calc_energy_category(categories, plugins, 'energy', tasks[x], prefix)

print(energy_category['all'])
print(sum(energy_category['all'].values()))
print(tasks['all']["total"]["energy"], tasks['all'][prefix + "other"]["energy"])
# Out:
# {'Integration Test': np.float64(354860.3960971458), 'Unit Test': np.float64(1852762.1644105918), 'Compile': np.float64(1464325.0512518506), 'Documentation': np.float64(313735.7402988593), 'Install': np.float64(16951.2923445133), 'Linter': np.float64(446080.48965294583), 'Packaging': np.float64(570833.9545845664), 'Others': np.float64(579353.799519699), 'Unclassified': np.float64(622871.8667809005)}
# 6221774.754941073
# 6221774.754941071 622871.8667809005

# %%
cat_ratios = {}
for key, value in energy_category.items():
    cat_ratios[key] = rq_aux.get_ratio_categories(value)
    
    
results_energy = { }
for x in sizes2:
    results_energy[x] = cat_ratios[x]
    

category_names = []
for key, value in energy_category['all'].items():
    category_names.append(categories_short[key]) 
    #category_names.append(key) 

labels = [re.sub(' ', '\n', x) for x in category_names]
rq_aux.survey(results_energy, labels)
plt.show()

# %%
n_category = {}

for x in sizes2:
  n_category[x] = rq_aux.calc_energy_category(categories, plugins, 'n', tasks[x], prefix)

print(n_category['all'])
print(sum(n_category['all'].values()))
print(tasks['all']["total"]["n"], tasks['all'][prefix + "other"]["n"])
# Out:
# {'Integration Test': np.int64(256), 'Unit Test': np.int64(2542), 'Compile': np.int64(8466), 'Documentation': np.int64(1888), 'Install': np.int64(114), 'Linter': np.int64(4035), 'Packaging': np.int64(11374), 'Others': np.int64(3319), 'Unclassified': np.int64(13265)}
# 45259
# 45259 13265

# %%
cat_ratios = {}
for key, value in n_category.items():
    cat_ratios[key] = rq_aux.get_ratio_categories(value)
    
    
results_n = { }
for x in sizes2:
    results_n[x] = cat_ratios[x]
    

category_names = []
for key, value in n_category['all'].items():
    category_names.append(categories_short[key]) 
    #category_names.append(key) 

labels = [re.sub(' ', '\n', x) for x in category_names]
rq_aux.survey(results_n, labels)
plt.show()

# %%
rq_aux.survey_two(results_energy, results_n, labels)

# %%
time_category = {}

for x in sizes2:
  time_category[x] = rq_aux.calc_energy_category(categories, plugins, 'seconds', tasks[x], prefix)

print(time_category['all'])
print(sum(time_category['all'].values()))
print(tasks['all']["total"]["seconds"], tasks['all'][prefix + "other"]["seconds"])
# Out:
# {'Integration Test': np.int64(17953594989), 'Unit Test': np.int64(78211393555), 'Compile': np.int64(78537017477), 'Documentation': np.int64(11751182850), 'Install': np.int64(1039070294), 'Linter': np.int64(18686002630), 'Packaging': np.int64(24107384739), 'Others': np.int64(28529614266), 'Unclassified': np.int64(28061991334)}
# 286877252134
# 286877252134 28061991334

# %%
cat_ratios = {}
for key, value in time_category.items():
    cat_ratios[key] = rq_aux.get_ratio_categories(value)
    
    
results = { }
for x in sizes2:
    results[x] = cat_ratios[x]
    

category_names = []
for key, value in time_category['all'].items():
    category_names.append(categories_short[key]) 
    #category_names.append(key) 

labels = [re.sub(' ', '\n', x) for x in category_names]
rq_aux.survey(results, labels)
plt.show()

# %%
df = rq_aux.read_all_tasks(alltasks_dataset, build_tool, noerror)
# Out:
# Tasks With Error: Removed 0 workflows: 181203 -> 181203
# Build tool gradle = 45259

# %%
df_verifier = df[df['kind'] == 'plugin-verifier']

# %%
df_verifier
# Out:
#                                                  file   size build_tool  \
# 9831   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9832   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9833   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9834   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9835   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9836   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9837   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9838   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 89725   halirutan_IntelliJ-Key-Promoter-X___build.yml  small     gradle
#
#                   kind        energy     seconds  has_error  error_msg
# 9831   plugin-verifier  21977.011567  1132037337      False        NaN
# 9832   plugin-verifier  20386.443613   910595326      False        NaN
# 9833   plugin-verifier  20229.765034   913548737      False        NaN
# 9834   plugin-verifier  11683.415565   521382122      False        NaN
# 9835   plugin-verifier   9632.792068   459516881      False        NaN
# 9836   plugin-verifier   2844.182497   126348435      False        NaN
# 9837   plugin-verifier   2710.532174   118640997      False        NaN
# 9838   plugin-verifier    740.107061    28500343      False        NaN
# 89725  plugin-verifier   3217.234795   280283399      False        NaN

# %%
len(df_verifier)
# Out:
# 9
