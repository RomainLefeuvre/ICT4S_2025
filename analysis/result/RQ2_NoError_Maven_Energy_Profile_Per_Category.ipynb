# %%
import pandas as pd
import sys
import importlib
sys.path.append("../scripts/")
import regex_maven
import rq_aux
import re
import matplotlib.pyplot as plt 
import seaborn as sns

importlib.reload(regex_maven)
importlib.reload(rq_aux)
 #"small", "medium", "large"
sizes1 = rq_aux.sizes1

#"all", "small", "medium", "large"
sizes2 = rq_aux.sizes2

# %%
regex = regex_maven
plugins = regex.plugins
categories = regex.categories
categories_short = regex.categories_short
prefix = "maven_"
build_tool = "maven"
is_build_tool = "is_maven"
noerror = True
output_path = "../data/output_data/"
overview_dataset = f"{output_path}overview_daylight_noerror.csv"
alltasks_dataset = f"{output_path}all_tasks_noerror.csv"

# %%
rq_aux.check_categories(regex)

# %%
df = rq_aux.read_all_tasks(alltasks_dataset, build_tool, noerror)
# Out:
# Tasks With Error: Removed 0 workflows: 181203 -> 181203
# Build tool maven = 135944

# %%
tasks = {}
for x in sizes1:
  tasks[x] = rq_aux.get_tasks_by_kind(df[df["size"] == x], plugins)

tasks['all'] = rq_aux.get_tasks_by_kind(df, plugins)

# %%
sum_tasks = {}
for x in sizes2:
  sum_tasks[x] = rq_aux.calc_energy_by_task(tasks[x])

# %%
for x in sizes2:
  print(f"**** {x.title()} ****")
  rq_aux.print_all_tasks(rq_aux.filter_tasks_by(sum_tasks[x], '', 0.005))
  print("")
# Out:
# **** All ****
# total: Energy: 20243266.621575635 (100.0%)
# surefire: Energy: 7787787.744102805 (38.5%)
# archetype-update: Energy: 3204375.4461364676 (15.8%)
# failsafe: Energy: 1507843.0673714953 (7.4%)
# compile: Energy: 933719.8143146395 (4.6%)
# install: Energy: 922646.8005067199 (4.6%)
# jacoco: Energy: 812754.6699662172 (4.0%)
# testcomp: Energy: 546362.5828158673 (2.7%)
# javadoc: Energy: 527244.4002109991 (2.6%)
# other: Energy: 419891.67810205306 (2.1%)
# source: Energy: 359900.3795047035 (1.8%)
# surefire-report: Energy: 331350.01666783064 (1.6%)
# checkstyle: Energy: 254150.7879698728 (1.3%)
# spotless: Energy: 216777.88540358175 (1.1%)
# frontend: Energy: 201547.39077740375 (1.0%)
# bundle: Energy: 142387.76250695513 (0.7%)
# antrun: Energy: 134569.81949318387 (0.7%)
# shade: Energy: 134370.40079368377 (0.7%)
# license: Energy: 131447.93046479084 (0.6%)
# jar: Energy: 119614.94088362159 (0.6%)
# gpg: Energy: 112646.7506415409 (0.6%)
# assembly: Energy: 101915.81860325215 (0.5%)
#
# **** Small ****
# total: Energy: 618145.3455386658 (100.0%)
# surefire: Energy: 157746.30060735362 (25.5%)
# javadoc: Energy: 157420.44625474006 (25.5%)
# checkstyle: Energy: 39573.518747656766 (6.4%)
# git-commit-id: Energy: 31874.390578375645 (5.2%)
# frontend: Energy: 30960.61221441816 (5.0%)
# rewrite: Energy: 30478.21224843296 (4.9%)
# compile: Energy: 22809.525302626458 (3.7%)
# spotless: Energy: 15536.089259884986 (2.5%)
# testcomp: Energy: 13371.555779414939 (2.2%)
# jar: Energy: 13241.657906727696 (2.1%)
# other: Energy: 8501.533983928663 (1.4%)
# dependency-check: Energy: 8225.073733072342 (1.3%)
# clean: Energy: 8101.1317227611735 (1.3%)
# dependency: Energy: 7331.154251030662 (1.2%)
# bundle: Energy: 6189.0536962517535 (1.0%)
# enforcer: Energy: 5911.468419942034 (1.0%)
# compile_k: Energy: 4680.807093142083 (0.8%)
# formatter: Energy: 4239.087856093621 (0.7%)
# clirr: Energy: 4234.135135945852 (0.7%)
# site: Energy: 3820.48033520769 (0.6%)
# resources: Energy: 3725.1452312265174 (0.6%)
# gplus: Energy: 3252.8689550241993 (0.5%)
# jacoco: Energy: 3136.290042813039 (0.5%)
#
# **** Medium ****
# total: Energy: 9780473.18975454 (100.0%)
# archetype-update: Energy: 3204373.2314854045 (32.8%)
# surefire: Energy: 2966233.2384934076 (30.3%)
# failsafe: Energy: 768544.9147486466 (7.9%)
# install: Energy: 672693.4633502589 (6.9%)
# source: Energy: 243811.33583916107 (2.5%)
# compile: Energy: 239376.09149877934 (2.4%)
# other: Energy: 221910.77679802405 (2.3%)
# testcomp: Energy: 184764.14928161632 (1.9%)
# spotless: Energy: 179944.04608888525 (1.8%)
# antrun: Energy: 115651.33617238555 (1.2%)
# gpg: Energy: 112337.28865337484 (1.1%)
# javadoc: Energy: 107176.58448915825 (1.1%)
# jacoco: Energy: 63731.26985532145 (0.7%)
# jar: Energy: 53929.083973854504 (0.6%)
# invoker: Energy: 53015.0755870857 (0.5%)
#
# **** Large ****
# total: Energy: 9844648.086282458 (100.0%)
# surefire: Energy: 4663808.205002087 (47.4%)
# jacoco: Energy: 745887.1100680837 (7.6%)
# failsafe: Energy: 738872.3771169021 (7.5%)
# compile: Energy: 671534.1975132332 (6.8%)
# testcomp: Energy: 348226.8777548346 (3.5%)
# surefire-report: Energy: 331350.01666783064 (3.4%)
# javadoc: Energy: 262647.36946709926 (2.7%)
# install: Energy: 247720.69351738543 (2.5%)
# other: Energy: 189479.3673200991 (1.9%)
# checkstyle: Energy: 178602.9481776198 (1.8%)
# frontend: Energy: 127926.91909828513 (1.3%)
# bundle: Energy: 122618.93806690519 (1.2%)
# license: Energy: 118915.61249333833 (1.2%)
# source: Energy: 113411.27711493944 (1.2%)
# shade: Energy: 112096.12994503231 (1.1%)
# apache-rat: Energy: 98436.70786429787 (1.0%)
# assembly: Energy: 81853.30598795081 (0.8%)
# site: Energy: 69771.61402158276 (0.7%)
# spotbugs: Energy: 67001.59998001294 (0.7%)
# fmt: Energy: 62564.64827249706 (0.6%)
# remote: Energy: 54929.46572320551 (0.6%)
# jar: Energy: 52444.19900303937 (0.5%)

# %%
df = pd.read_csv(overview_dataset)

# Remove Maven Workflows Without Maven Subtasks
df = rq_aux.remove_workflows_no_subtask(df[df[is_build_tool]], prefix, plugins)

df_size = rq_aux.create_dfs_size(df, is_build_tool)
# Out:
# Workflows No Subtask: Removed 207 workflows: 938 -> 731

# %%
# Calculate maven-related energy consumption for all maven workflows
tasks = {}

for x in sizes2:
  print(f"*** {x.title()} ***")
  tasks[x] = rq_aux.calc_sum(df_size[x], prefix, plugins)
  rq_aux.calc_workflow_energy_proportion (df_size[x], tasks[x])
  rq_aux.calc_ratio(tasks[x])
  print(f"{df_size[x]['energy'].sum():0.2f}")
# Out:
# *** All ***
# Energy:  20243267 (24.5%)
# Seconds:  1095565692628 (20.3%)
# 82605467.26
# *** Small ***
# Energy:  618145 (37.3%)
# Seconds:  35638455380 (35.3%)
# 1655321.52
# *** Medium ***
# Energy:  9780473 (37.6%)
# Seconds:  459737496565 (31.0%)
# 25997316.12
# *** Large ***
# Energy:  9844648 (17.9%)
# Seconds:  600189740683 (15.7%)
# 54952829.62
# /home/rlefeuvr/Documents/Workspace/ICT4S_2025/energy-CI-CD/analysis/../scripts/rq_aux.py:46: RuntimeWarning: invalid value encountered in scalar divide
#   return round(100 * x / y, n)

# %%
for x in sizes2:
  print(f"**** {x.title()} ****")
  rq_aux.print_tasks_summary(rq_aux.filter_tasks_by(tasks[x], 'energy', 0.02))
  print("")
# Out:
# **** All ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Maven_Surefire ***
# N:  6.1%;  Energy:  38.5%;  Seconds:  43.8%;  Rat_P:  nan%;  Rat_N:  630.3%;
# *** Maven_Archetype-Update ***
# N:  0.1%;  Energy:  15.8%;  Seconds:  9.5%;  Rat_P:  nan%;  Rat_N:  29887.5%;
# *** Maven_Failsafe ***
# N:  0.4%;  Energy:  7.4%;  Seconds:  10.3%;  Rat_P:  nan%;  Rat_N:  1954.8%;
# *** Maven_Compile ***
# N:  15.0%;  Energy:  4.6%;  Seconds:  3.3%;  Rat_P:  nan%;  Rat_N:  30.8%;
# *** Maven_Install ***
# N:  4.7%;  Energy:  4.6%;  Seconds:  5.1%;  Rat_P:  nan%;  Rat_N:  96.8%;
# *** Maven_Jacoco ***
# N:  3.0%;  Energy:  4.0%;  Seconds:  3.3%;  Rat_P:  nan%;  Rat_N:  134.2%;
# *** Maven_Testcomp ***
# N:  10.4%;  Energy:  2.7%;  Seconds:  1.7%;  Rat_P:  nan%;  Rat_N:  26.0%;
# *** Maven_Javadoc ***
# N:  2.5%;  Energy:  2.6%;  Seconds:  2.6%;  Rat_P:  nan%;  Rat_N:  105.3%;
# *** Maven_Other ***
# N:  4.7%;  Energy:  2.1%;  Seconds:  2.6%;  Rat_P:  nan%;  Rat_N:  44.1%;
#
# **** Small ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Maven_Surefire ***
# N:  10.1%;  Energy:  25.5%;  Seconds:  28.6%;  Rat_P:  nan%;  Rat_N:  253.0%;
# *** Maven_Javadoc ***
# N:  3.2%;  Energy:  25.5%;  Seconds:  27.7%;  Rat_P:  nan%;  Rat_N:  787.8%;
# *** Maven_Checkstyle ***
# N:  1.3%;  Energy:  6.4%;  Seconds:  5.2%;  Rat_P:  nan%;  Rat_N:  480.7%;
# *** Maven_Git-Commit-Id ***
# N:  5.0%;  Energy:  5.2%;  Seconds:  5.6%;  Rat_P:  nan%;  Rat_N:  102.3%;
# *** Maven_Frontend ***
# N:  1.3%;  Energy:  5.0%;  Seconds:  4.5%;  Rat_P:  nan%;  Rat_N:  379.8%;
# *** Maven_Rewrite ***
# N:  0.7%;  Energy:  4.9%;  Seconds:  4.0%;  Rat_P:  nan%;  Rat_N:  706.2%;
# *** Maven_Compile ***
# N:  12.2%;  Energy:  3.7%;  Seconds:  2.8%;  Rat_P:  nan%;  Rat_N:  30.4%;
# *** Maven_Spotless ***
# N:  0.7%;  Energy:  2.5%;  Seconds:  2.6%;  Rat_P:  nan%;  Rat_N:  335.1%;
# *** Maven_Testcomp ***
# N:  9.1%;  Energy:  2.2%;  Seconds:  1.2%;  Rat_P:  nan%;  Rat_N:  23.8%;
# *** Maven_Jar ***
# N:  5.5%;  Energy:  2.1%;  Seconds:  2.2%;  Rat_P:  nan%;  Rat_N:  38.9%;
#
# **** Medium ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Maven_Archetype-Update ***
# N:  0.1%;  Energy:  32.8%;  Seconds:  22.8%;  Rat_P:  nan%;  Rat_N:  22889.8%;
# *** Maven_Surefire ***
# N:  7.1%;  Energy:  30.3%;  Seconds:  31.5%;  Rat_P:  nan%;  Rat_N:  427.8%;
# *** Maven_Failsafe ***
# N:  0.4%;  Energy:  7.9%;  Seconds:  12.8%;  Rat_P:  nan%;  Rat_N:  1978.6%;
# *** Maven_Install ***
# N:  4.5%;  Energy:  6.9%;  Seconds:  7.9%;  Rat_P:  nan%;  Rat_N:  153.8%;
# *** Maven_Source ***
# N:  4.6%;  Energy:  2.5%;  Seconds:  2.2%;  Rat_P:  nan%;  Rat_N:  54.6%;
# *** Maven_Compile ***
# N:  14.3%;  Energy:  2.4%;  Seconds:  2.0%;  Rat_P:  nan%;  Rat_N:  17.1%;
# *** Maven_Other ***
# N:  5.7%;  Energy:  2.3%;  Seconds:  3.6%;  Rat_P:  nan%;  Rat_N:  40.0%;
#
# **** Large ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Maven_Surefire ***
# N:  5.1%;  Energy:  47.4%;  Seconds:  54.0%;  Rat_P:  nan%;  Rat_N:  930.7%;
# *** Maven_Jacoco ***
# N:  3.5%;  Energy:  7.6%;  Seconds:  5.2%;  Rat_P:  nan%;  Rat_N:  218.9%;
# *** Maven_Failsafe ***
# N:  0.4%;  Energy:  7.5%;  Seconds:  9.0%;  Rat_P:  nan%;  Rat_N:  1849.4%;
# *** Maven_Compile ***
# N:  15.7%;  Energy:  6.8%;  Seconds:  4.3%;  Rat_P:  nan%;  Rat_N:  43.6%;
# *** Maven_Testcomp ***
# N:  10.8%;  Energy:  3.5%;  Seconds:  2.0%;  Rat_P:  nan%;  Rat_N:  32.8%;
# *** Maven_Surefire-Report ***
# N:  0.1%;  Energy:  3.4%;  Seconds:  3.7%;  Rat_P:  nan%;  Rat_N:  6614.3%;
# *** Maven_Javadoc ***
# N:  1.8%;  Energy:  2.7%;  Seconds:  2.2%;  Rat_P:  nan%;  Rat_N:  151.1%;
# *** Maven_Install ***
# N:  5.2%;  Energy:  2.5%;  Seconds:  3.2%;  Rat_P:  nan%;  Rat_N:  48.7%;

# %%
energy_category = {}

for x in sizes2:
  energy_category[x] = rq_aux.calc_energy_category(categories, plugins, 'energy', tasks[x], prefix)

print(energy_category['all'])
print(sum(energy_category['all'].values()))
print(tasks['all']["total"]["energy"], tasks['all'][prefix + "other"]["energy"])
# Out:
# {'Integration Test': np.float64(1509835.2357659503), 'Unit Test': np.float64(8140048.749245136), 'Compile': np.float64(1673435.007056701), 'Documentation': np.float64(658588.4172758933), 'Install': np.float64(4127022.246643188), 'Linter': np.float64(1534887.7922470886), 'Packaging': np.float64(812974.3945034377), 'Others': np.float64(1366583.100736189), 'Unclassified': np.float64(419891.6781020521)}
# 20243266.621575635
# 20243266.621575646 419891.6781020521

# %%
cat_ratios = {}
for key, value in energy_category.items():
    cat_ratios[key] = rq_aux.get_ratio_categories(value)
    
    
results_energy = { }
for x in sizes2:
    results_energy[x] = cat_ratios[x]
    

category_names = []
for key, value in energy_category['all'].items():
    category_names.append(categories_short[key]) 
    #category_names.append(key) 

labels = [re.sub(' ', '\n', x) for x in category_names]
rq_aux.survey(results_energy, labels)
plt.show()

# %%
n_category = {}

for x in sizes2:
  n_category[x] = rq_aux.calc_energy_category(categories, plugins, 'n', tasks[x], prefix)

print(n_category['all'])
print(sum(n_category['all'].values()))
print(tasks['all']["total"]["n"], tasks['all'][prefix + "other"]["n"])
# Out:
# {'Integration Test': np.int64(589), 'Unit Test': np.int64(8403), 'Compile': np.int64(37027), 'Documentation': np.int64(4596), 'Install': np.int64(6472), 'Linter': np.int64(18083), 'Packaging': np.int64(22892), 'Others': np.int64(31488), 'Unclassified': np.int64(6394)}
# 135944
# 135944 6394

# %%
cat_ratios = {}
for key, value in n_category.items():
    cat_ratios[key] = rq_aux.get_ratio_categories(value)
    
    
results_n = { }
for x in sizes2:
    results_n[x] = cat_ratios[x]
    

category_names = []
for key, value in n_category['all'].items():
    category_names.append(categories_short[key]) 
    #category_names.append(key) 

labels = [re.sub(' ', '\n', x) for x in category_names]
rq_aux.survey(results_n, labels)
plt.show()

# %%
rq_aux.survey_two(results_energy, results_n, labels)

# %%
time_category = {}

for x in sizes2:
  time_category[x] = rq_aux.calc_energy_category(categories, plugins, 'seconds', tasks[x], prefix)

print(time_category['all'])
print(sum(time_category['all'].values()))
print(tasks['all']["total"]["seconds"], tasks['all'][prefix + "other"]["seconds"])
# Out:
# {'Integration Test': np.int64(112896072768), 'Unit Test': np.int64(502525947393), 'Compile': np.int64(62113470067), 'Documentation': np.int64(41871810230), 'Install': np.int64(160025949415), 'Linter': np.int64(78590991979), 'Packaging': np.int64(40481580531), 'Others': np.int64(69023787885), 'Unclassified': np.int64(28036082360)}
# 1095565692628
# 1095565692628 28036082360

# %%
cat_ratios = {}
for key, value in time_category.items():
    cat_ratios[key] = rq_aux.get_ratio_categories(value)
    
    
results = { }
for x in sizes2:
    results[x] = cat_ratios[x]
    

category_names = []
for key, value in time_category['all'].items():
    category_names.append(categories_short[key]) 
    #category_names.append(key) 

labels = [re.sub(' ', '\n', x) for x in category_names]
rq_aux.survey(results, labels)
plt.show()

# %%
print(len(regex_maven.plugins))
# Out:
# 73

# %%
df = rq_aux.read_all_tasks(alltasks_dataset, build_tool, noerror)
# Out:
# Tasks With Error: Removed 0 workflows: 181203 -> 181203
# Build tool maven = 135944

# %%
df_arch_up = df[df['kind'] == 'archetype-update']

# %%
df_arch_up
# Out:
#                                      file    size build_tool  \
# 137478  openjdk_jmh___pre-integration.yml  medium      maven
# 137479  openjdk_jmh___pre-integration.yml  medium      maven
# 137480  openjdk_jmh___pre-integration.yml  medium      maven
# 137481  openjdk_jmh___pre-integration.yml  medium      maven
# 137482  openjdk_jmh___pre-integration.yml  medium      maven
# ...                                   ...     ...        ...
# 141164  openjdk_jmh___pre-integration.yml  medium      maven
# 141193  openjdk_jmh___pre-integration.yml  medium      maven
# 141331  openjdk_jmh___pre-integration.yml  medium      maven
# 141469  openjdk_jmh___pre-integration.yml  medium      maven
# 146203         oracle_graal___quarkus.yml   large      maven
#
#                     kind        energy      seconds  has_error  error_msg
# 137478  archetype-update  1.069865e+06  34955634735      False        NaN
# 137479  archetype-update  8.390437e+05  27367353278      False        NaN
# 137480  archetype-update  4.669518e+05  15217439242      False        NaN
# 137481  archetype-update  4.407678e+05  14492593094      False        NaN
# 137482  archetype-update  3.853909e+05  12484375245      False        NaN
# ...                  ...           ...          ...        ...        ...
# 141164  archetype-update  3.168655e+00         2812      False        NaN
# 141193  archetype-update  3.156070e+00        10042      False        NaN
# 141331  archetype-update  3.083922e+00        22917      False        NaN
# 141469  archetype-update  2.998984e+00        10980      False        NaN
# 146203  archetype-update  2.214651e+00        16382      False        NaN
#
# [72 rows x 8 columns]

# %%
len(df_arch_up[df_arch_up['size'] == 'medium'])
# Out:
# 71
