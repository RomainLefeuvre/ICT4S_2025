# %%
import pandas as pd
import sys
import importlib
sys.path.append("../scripts/")
import regex_maven
import rq_aux
import re
import matplotlib.pyplot as plt 
import seaborn as sns

importlib.reload(regex_maven)
importlib.reload(rq_aux)
 #"small", "medium", "large"
sizes1 = rq_aux.sizes1

#"all", "small", "medium", "large"
sizes2 = rq_aux.sizes2

# %%
regex = regex_maven
plugins = regex.plugins
categories = regex.categories
categories_short = regex.categories_short
prefix = "maven_"
build_tool = "maven"
is_build_tool = "is_maven"
noerror = True
output_path = "../data/output_data/"
#overview_dataset = f"{output_path}overview_daylight_noerror.csv"
#alltasks_dataset = f"{output_path}all_tasks_noerror.csv"

overview_dataset = f"{output_path}overview_cloc2_noerror.csv"
alltasks_dataset = f"{output_path}all_tasks_cloc2_noerror.csv"

# %%
rq_aux.check_categories(regex)

# %%
df = rq_aux.read_all_tasks(alltasks_dataset, build_tool, noerror)
# Out:
# Tasks With Error: Removed 0 workflows: 183355 -> 183355
# Build tool maven = 137333

# %%
tasks = {}
for x in sizes1:
  tasks[x] = rq_aux.get_tasks_by_kind(df[df["size"] == x], plugins)

tasks['all'] = rq_aux.get_tasks_by_kind(df, plugins)

# %%
sum_tasks = {}
for x in sizes2:
  sum_tasks[x] = rq_aux.calc_energy_by_task(tasks[x])

# %%
for x in sizes2:
  print(f"**** {x.title()} ****")
  rq_aux.print_all_tasks(rq_aux.filter_tasks_by(sum_tasks[x], '', 0.005))
  print("")
# Out:
# **** All ****
# total: Energy: 20307582.986063533 (100.0%)
# surefire: Energy: 7796911.733151135 (38.4%)
# archetype-update: Energy: 3204375.4461364676 (15.8%)
# failsafe: Energy: 1507843.0673714953 (7.4%)
# compile: Energy: 951833.8920114206 (4.7%)
# install: Energy: 924201.077625588 (4.6%)
# jacoco: Energy: 813013.2433833756 (4.0%)
# testcomp: Energy: 557837.9762774397 (2.7%)
# javadoc: Energy: 527314.186842948 (2.6%)
# other: Energy: 422197.99533118494 (2.1%)
# source: Energy: 361671.8916007576 (1.8%)
# surefire-report: Energy: 331350.01666783064 (1.6%)
# checkstyle: Energy: 258483.67541312033 (1.3%)
# spotless: Energy: 217035.62839642493 (1.1%)
# frontend: Energy: 202247.6467329397 (1.0%)
# bundle: Energy: 143213.07726977926 (0.7%)
# antrun: Energy: 134604.37315698943 (0.7%)
# shade: Energy: 134461.56154619786 (0.7%)
# license: Energy: 131466.95567648805 (0.6%)
# jar: Energy: 120529.19427523503 (0.6%)
# gpg: Energy: 112646.75064154089 (0.6%)
# assembly: Energy: 103304.71911296833 (0.5%)
#
# **** Small ****
# total: Energy: 618145.3455386658 (100.0%)
# surefire: Energy: 157746.30060735362 (25.5%)
# javadoc: Energy: 157420.44625474006 (25.5%)
# checkstyle: Energy: 39573.518747656766 (6.4%)
# git-commit-id: Energy: 31874.390578375645 (5.2%)
# frontend: Energy: 30960.61221441816 (5.0%)
# rewrite: Energy: 30478.21224843296 (4.9%)
# compile: Energy: 22809.525302626458 (3.7%)
# spotless: Energy: 15536.089259884986 (2.5%)
# testcomp: Energy: 13371.555779414939 (2.2%)
# jar: Energy: 13241.657906727696 (2.1%)
# other: Energy: 8501.533983928663 (1.4%)
# dependency-check: Energy: 8225.073733072342 (1.3%)
# clean: Energy: 8101.1317227611735 (1.3%)
# dependency: Energy: 7331.154251030662 (1.2%)
# bundle: Energy: 6189.0536962517535 (1.0%)
# enforcer: Energy: 5911.468419942034 (1.0%)
# compile_k: Energy: 4680.807093142083 (0.8%)
# formatter: Energy: 4239.08785609362 (0.7%)
# clirr: Energy: 4234.135135945852 (0.7%)
# site: Energy: 3820.48033520769 (0.6%)
# resources: Energy: 3725.1452312265174 (0.6%)
# gplus: Energy: 3252.8689550241993 (0.5%)
# jacoco: Energy: 3136.290042813039 (0.5%)
#
# **** Medium ****
# total: Energy: 9795752.582969584 (100.0%)
# archetype-update: Energy: 3204373.2314854045 (32.7%)
# surefire: Energy: 2974075.96949314 (30.4%)
# failsafe: Energy: 768544.9147486466 (7.8%)
# install: Energy: 673459.7126681824 (6.9%)
# source: Energy: 243841.42843840888 (2.5%)
# compile: Energy: 240452.58450132547 (2.5%)
# other: Energy: 221998.14170907764 (2.3%)
# testcomp: Energy: 185814.6672780158 (1.9%)
# spotless: Energy: 179944.04608888525 (1.8%)
# antrun: Energy: 115651.33617238556 (1.2%)
# gpg: Energy: 112337.28865337484 (1.1%)
# javadoc: Energy: 107246.37112110724 (1.1%)
# jacoco: Energy: 63731.26985532145 (0.7%)
# jar: Energy: 54256.72782358446 (0.6%)
# invoker: Energy: 53015.0755870857 (0.5%)
#
# **** Large ****
# total: Energy: 9893685.057555318 (100.0%)
# surefire: Energy: 4665089.463050687 (47.2%)
# jacoco: Energy: 746145.6834852421 (7.5%)
# failsafe: Energy: 738872.3771169021 (7.5%)
# compile: Energy: 688571.782207468 (7.0%)
# testcomp: Energy: 358651.7532200079 (3.6%)
# surefire-report: Energy: 331350.01666783064 (3.3%)
# javadoc: Energy: 262647.3694670992 (2.7%)
# install: Energy: 248508.72131832998 (2.5%)
# other: Energy: 191698.3196381773 (1.9%)
# checkstyle: Energy: 181834.73008201245 (1.8%)
# frontend: Energy: 127926.91909828513 (1.3%)
# bundle: Energy: 123020.56655941646 (1.2%)
# license: Energy: 118934.63770503555 (1.2%)
# source: Energy: 115152.69661174566 (1.2%)
# shade: Energy: 112126.08262623867 (1.1%)
# apache-rat: Energy: 98436.70786429787 (1.0%)
# assembly: Energy: 82076.86248576042 (0.8%)
# site: Energy: 69771.61402158276 (0.7%)
# spotbugs: Energy: 67001.59998001294 (0.7%)
# fmt: Energy: 62564.64827249705 (0.6%)
# remote: Energy: 54992.9445822389 (0.6%)
# jar: Energy: 53030.8085449228 (0.5%)

# %%
df = pd.read_csv(overview_dataset)

# Remove Maven Workflows Without Maven Subtasks
df = rq_aux.remove_workflows_no_subtask(df[df[is_build_tool]], prefix, plugins)

df_size = rq_aux.create_dfs_size(df, is_build_tool)
# Out:
# Workflows No Subtask: Removed 210 workflows: 950 -> 740

# %%
# Calculate maven-related energy consumption for all maven workflows
tasks = {}

for x in sizes2:
  print(f"*** {x.title()} ***")
  tasks[x] = rq_aux.calc_sum(df_size[x], prefix, plugins)
  rq_aux.calc_workflow_energy_proportion (df_size[x], tasks[x])
  rq_aux.calc_ratio(tasks[x])
  print(f"{df_size[x]['energy'].sum():0.2f}")
# Out:
# *** All ***
# Energy:  20307583 (24.4%)
# Seconds:  1098762177084 (20.2%)
# 83229394.26
# *** Small ***
# Energy:  618145 (37.3%)
# Seconds:  35638455380 (35.3%)
# 1655321.52
# *** Medium ***
# Energy:  9795753 (37.6%)
# Seconds:  460619837830 (31.0%)
# 26034957.97
# *** Large ***
# Energy:  9893685 (17.8%)
# Seconds:  602503883874 (15.6%)
# 55539114.76
# /Users/sergio/pesquisa/ICT4S_2025/analysis/../scripts/rq_aux.py:46: RuntimeWarning: invalid value encountered in scalar divide
#   return round(100 * x / y, n)

# %%
for x in sizes2:
  print(f"**** {x.title()} ****")
  rq_aux.print_tasks_summary(rq_aux.filter_tasks_by(tasks[x], 'energy', 0.02))
  print("")
# Out:
# **** All ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Maven_Surefire ***
# N:  6.1%;  Energy:  38.4%;  Seconds:  43.7%;  Rat_P:  nan%;  Rat_N:  630.3%;
# *** Maven_Archetype-Update ***
# N:  0.1%;  Energy:  15.8%;  Seconds:  9.5%;  Rat_P:  nan%;  Rat_N:  30097.3%;
# *** Maven_Failsafe ***
# N:  0.4%;  Energy:  7.4%;  Seconds:  10.3%;  Rat_P:  nan%;  Rat_N:  1968.5%;
# *** Maven_Compile ***
# N:  15.0%;  Energy:  4.7%;  Seconds:  3.3%;  Rat_P:  nan%;  Rat_N:  31.3%;
# *** Maven_Install ***
# N:  4.7%;  Energy:  4.6%;  Seconds:  5.1%;  Rat_P:  nan%;  Rat_N:  96.3%;
# *** Maven_Jacoco ***
# N:  3.0%;  Energy:  4.0%;  Seconds:  3.3%;  Rat_P:  nan%;  Rat_N:  134.7%;
# *** Maven_Testcomp ***
# N:  10.4%;  Energy:  2.7%;  Seconds:  1.7%;  Rat_P:  nan%;  Rat_N:  26.5%;
# *** Maven_Javadoc ***
# N:  2.4%;  Energy:  2.6%;  Seconds:  2.6%;  Rat_P:  nan%;  Rat_N:  106.1%;
# *** Maven_Other ***
# N:  4.7%;  Energy:  2.1%;  Seconds:  2.6%;  Rat_P:  nan%;  Rat_N:  44.2%;
#
# **** Small ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Maven_Surefire ***
# N:  10.1%;  Energy:  25.5%;  Seconds:  28.6%;  Rat_P:  nan%;  Rat_N:  253.0%;
# *** Maven_Javadoc ***
# N:  3.2%;  Energy:  25.5%;  Seconds:  27.7%;  Rat_P:  nan%;  Rat_N:  787.8%;
# *** Maven_Checkstyle ***
# N:  1.3%;  Energy:  6.4%;  Seconds:  5.2%;  Rat_P:  nan%;  Rat_N:  480.7%;
# *** Maven_Git-Commit-Id ***
# N:  5.0%;  Energy:  5.2%;  Seconds:  5.6%;  Rat_P:  nan%;  Rat_N:  102.3%;
# *** Maven_Frontend ***
# N:  1.3%;  Energy:  5.0%;  Seconds:  4.5%;  Rat_P:  nan%;  Rat_N:  379.8%;
# *** Maven_Rewrite ***
# N:  0.7%;  Energy:  4.9%;  Seconds:  4.0%;  Rat_P:  nan%;  Rat_N:  706.2%;
# *** Maven_Compile ***
# N:  12.2%;  Energy:  3.7%;  Seconds:  2.8%;  Rat_P:  nan%;  Rat_N:  30.4%;
# *** Maven_Spotless ***
# N:  0.7%;  Energy:  2.5%;  Seconds:  2.6%;  Rat_P:  nan%;  Rat_N:  335.1%;
# *** Maven_Testcomp ***
# N:  9.1%;  Energy:  2.2%;  Seconds:  1.2%;  Rat_P:  nan%;  Rat_N:  23.8%;
# *** Maven_Jar ***
# N:  5.5%;  Energy:  2.1%;  Seconds:  2.2%;  Rat_P:  nan%;  Rat_N:  38.9%;
#
# **** Medium ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Maven_Archetype-Update ***
# N:  0.1%;  Energy:  32.7%;  Seconds:  22.7%;  Rat_P:  nan%;  Rat_N:  23019.5%;
# *** Maven_Surefire ***
# N:  7.2%;  Energy:  30.4%;  Seconds:  31.5%;  Rat_P:  nan%;  Rat_N:  424.6%;
# *** Maven_Failsafe ***
# N:  0.4%;  Energy:  7.8%;  Seconds:  12.8%;  Rat_P:  nan%;  Rat_N:  1989.8%;
# *** Maven_Install ***
# N:  4.5%;  Energy:  6.9%;  Seconds:  7.9%;  Rat_P:  nan%;  Rat_N:  154.5%;
# *** Maven_Source ***
# N:  4.5%;  Energy:  2.5%;  Seconds:  2.1%;  Rat_P:  nan%;  Rat_N:  54.9%;
# *** Maven_Compile ***
# N:  14.4%;  Energy:  2.5%;  Seconds:  2.1%;  Rat_P:  nan%;  Rat_N:  17.1%;
# *** Maven_Other ***
# N:  5.6%;  Energy:  2.3%;  Seconds:  3.6%;  Rat_P:  nan%;  Rat_N:  40.1%;
#
# **** Large ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Maven_Surefire ***
# N:  5.0%;  Energy:  47.2%;  Seconds:  53.9%;  Rat_P:  nan%;  Rat_N:  935.9%;
# *** Maven_Jacoco ***
# N:  3.4%;  Energy:  7.5%;  Seconds:  5.2%;  Rat_P:  nan%;  Rat_N:  219.5%;
# *** Maven_Failsafe ***
# N:  0.4%;  Energy:  7.5%;  Seconds:  9.0%;  Rat_P:  nan%;  Rat_N:  1864.4%;
# *** Maven_Compile ***
# N:  15.6%;  Energy:  7.0%;  Seconds:  4.4%;  Rat_P:  nan%;  Rat_N:  44.5%;
# *** Maven_Testcomp ***
# N:  10.7%;  Energy:  3.6%;  Seconds:  2.1%;  Rat_P:  nan%;  Rat_N:  33.7%;
# *** Maven_Surefire-Report ***
# N:  0.1%;  Energy:  3.3%;  Seconds:  3.7%;  Rat_P:  nan%;  Rat_N:  6667.8%;
# *** Maven_Javadoc ***
# N:  1.7%;  Energy:  2.7%;  Seconds:  2.2%;  Rat_P:  nan%;  Rat_N:  152.3%;
# *** Maven_Install ***
# N:  5.2%;  Energy:  2.5%;  Seconds:  3.1%;  Rat_P:  nan%;  Rat_N:  48.3%;

# %%
energy_category = {}

for x in sizes2:
  energy_category[x] = rq_aux.calc_energy_category(categories, plugins, 'energy', tasks[x], prefix)

print(energy_category['all'])
print(sum(energy_category['all'].values()))
print(tasks['all']["total"]["energy"], tasks['all'][prefix + "other"]["energy"])
# Out:
# {'Integration Test': 1509835.2357659503, 'Unit Test': 8149172.738293465, 'Compile': 1704448.497080545, 'Documentation': 658658.2039078423, 'Install': 4128576.5237620557, 'Linter': 1539879.8954139084, 'Packaging': 820275.4051418037, 'Others': 1374538.4913667778, 'Unclassified': 422197.9953311839}
# 20307582.986063533
# 20307582.98606354 422197.9953311839

# %%
cat_ratios = {}
for key, value in energy_category.items():
    cat_ratios[key] = rq_aux.get_ratio_categories(value)
    
    
results_energy = { }
for x in sizes2:
    results_energy[x] = cat_ratios[x]
    

category_names = []
for key, value in energy_category['all'].items():
    category_names.append(categories_short[key]) 
    #category_names.append(key) 

labels = [re.sub(' ', '\n', x) for x in category_names]
rq_aux.survey(results_energy, labels)
plt.show()

# %%
n_category = {}

for x in sizes2:
  n_category[x] = rq_aux.calc_energy_category(categories, plugins, 'n', tasks[x], prefix)

print(n_category['all'])
print(sum(n_category['all'].values()))
print(tasks['all']["total"]["n"], tasks['all'][prefix + "other"]["n"])
# Out:
# {'Integration Test': 589, 'Unit Test': 8470, 'Compile': 37431, 'Documentation': 4597, 'Install': 6559, 'Linter': 18259, 'Packaging': 23200, 'Others': 31764, 'Unclassified': 6464}
# 137333
# 137333 6464

# %%
cat_ratios = {}
for key, value in n_category.items():
    cat_ratios[key] = rq_aux.get_ratio_categories(value)
    
    
results_n = { }
for x in sizes2:
    results_n[x] = cat_ratios[x]
    

category_names = []
for key, value in n_category['all'].items():
    category_names.append(categories_short[key]) 
    #category_names.append(key) 

labels = [re.sub(' ', '\n', x) for x in category_names]
rq_aux.survey(results_n, labels)
plt.show()

# %%
rq_aux.survey_two(results_energy, results_n, labels)

# %%
time_category = {}

for x in sizes2:
  time_category[x] = rq_aux.calc_energy_category(categories, plugins, 'seconds', tasks[x], prefix)

print(time_category['all'])
print(sum(time_category['all'].values()))
print(tasks['all']["total"]["seconds"], tasks['all'][prefix + "other"]["seconds"])
# Out:
# {'Integration Test': 112896072768, 'Unit Test': 503028323050, 'Compile': 63344705151, 'Documentation': 41875634210, 'Install': 160116862095, 'Linter': 78847872477, 'Packaging': 41006830083, 'Others': 69426248847, 'Unclassified': 28219628403}
# 1098762177084
# 1098762177084 28219628403

# %%
cat_ratios = {}
for key, value in time_category.items():
    cat_ratios[key] = rq_aux.get_ratio_categories(value)
    
    
results = { }
for x in sizes2:
    results[x] = cat_ratios[x]
    

category_names = []
for key, value in time_category['all'].items():
    category_names.append(categories_short[key]) 
    #category_names.append(key) 

labels = [re.sub(' ', '\n', x) for x in category_names]
rq_aux.survey(results, labels)
plt.show()

# %%
print(len(regex_maven.plugins))
# Out:
# 73

# %%
df = rq_aux.read_all_tasks(alltasks_dataset, build_tool, noerror)
# Out:
# Tasks With Error: Removed 0 workflows: 183355 -> 183355
# Build tool maven = 137333

# %%
df_arch_up = df[df['kind'] == 'archetype-update']

# %%
df_arch_up
# Out:
#                                      file    size build_tool  \
# 139118  openjdk_jmh___pre-integration.yml  medium      maven
# 139119  openjdk_jmh___pre-integration.yml  medium      maven
# 139120  openjdk_jmh___pre-integration.yml  medium      maven
# 139121  openjdk_jmh___pre-integration.yml  medium      maven
# 139122  openjdk_jmh___pre-integration.yml  medium      maven
# ...                                   ...     ...        ...
# 142804  openjdk_jmh___pre-integration.yml  medium      maven
# 142833  openjdk_jmh___pre-integration.yml  medium      maven
# 142971  openjdk_jmh___pre-integration.yml  medium      maven
# 143109  openjdk_jmh___pre-integration.yml  medium      maven
# 147843         oracle_graal___quarkus.yml   large      maven
#
#                     kind        energy      seconds  has_error  error_msg
# 139118  archetype-update  1.069865e+06  34955634735      False        NaN
# 139119  archetype-update  8.390437e+05  27367353278      False        NaN
# 139120  archetype-update  4.669518e+05  15217439242      False        NaN
# 139121  archetype-update  4.407678e+05  14492593094      False        NaN
# 139122  archetype-update  3.853909e+05  12484375245      False        NaN
# ...                  ...           ...          ...        ...        ...
# 142804  archetype-update  3.168655e+00         2812      False        NaN
# 142833  archetype-update  3.156070e+00        10042      False        NaN
# 142971  archetype-update  3.083922e+00        22917      False        NaN
# 143109  archetype-update  2.998984e+00        10980      False        NaN
# 147843  archetype-update  2.214651e+00        16382      False        NaN
#
# [72 rows x 8 columns]

# %%
len(df_arch_up[df_arch_up['size'] == 'medium'])
# Out:
# 71
