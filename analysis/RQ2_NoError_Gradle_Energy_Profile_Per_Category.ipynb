# %%
import pandas as pd
import sys
import importlib
sys.path.append("../scripts/")
import regex_gradle
import rq_aux
import re
import matplotlib.pyplot as plt 
import seaborn as sns

importlib.reload(regex_gradle)
importlib.reload(rq_aux)
 #"small", "medium", "large"
sizes1 = rq_aux.sizes1

#"all", "small", "medium", "large"
sizes2 = rq_aux.sizes2

# %%
regex = regex_gradle
plugins = regex.plugins
categories = regex.categories
categories_short = regex.categories_short
prefix = "gradle_"
build_tool = "gradle"
is_build_tool = "is_gradle"
noerror = True
output_path = "../data/output_data/"
#overview_dataset = f"{output_path}overview_daylight_noerror.csv"
#alltasks_dataset = f"{output_path}all_tasks_noerror.csv"

overview_dataset = f"{output_path}overview_cloc2_noerror.csv"
alltasks_dataset = f"{output_path}all_tasks_cloc2_noerror.csv"

# %%
rq_aux.check_categories(regex)

# %%
df = rq_aux.read_all_tasks(alltasks_dataset, build_tool, noerror)
# Out:
# Tasks With Error: Removed 0 workflows: 183355 -> 183355
# Build tool gradle = 46022

# %%
tasks = {}
for x in sizes1:
  tasks[x] = rq_aux.get_tasks_by_kind(df[df["size"] == x], plugins)

tasks['all'] = rq_aux.get_tasks_by_kind(df, plugins)

# %%
sum_tasks = {}
for x in sizes2:
  sum_tasks[x] = rq_aux.calc_energy_by_task(tasks[x])

# %%
for x in sizes2:
  print(f"**** {x.title()} ****")
  rq_aux.print_all_tasks(rq_aux.filter_tasks_by(sum_tasks[x], '', 0.02))
  print("")
# Out:
# **** All ****
# total: Energy: 6388768.076894071 (100.0%)
# test: Energy: 1857434.1588290243 (29.1%)
# jmh: Energy: 666912.250396649 (10.4%)
# other: Energy: 627508.2882072072 (9.8%)
# build: Energy: 287104.89979383413 (4.5%)
# javadoc: Energy: 285013.2394670046 (4.5%)
# publish: Energy: 261143.76227375818 (4.1%)
# func_test: Energy: 243159.86741640556 (3.8%)
# compile: Energy: 202475.830026166 (3.2%)
# jar: Energy: 199982.63423470547 (3.1%)
# build_src: Energy: 177420.7789023028 (2.8%)
# checkstyle: Energy: 168547.39532929013 (2.6%)
# test_class: Energy: 150216.05098475574 (2.4%)
#
# **** Small ****
# total: Energy: 162477.96577686045 (100.0%)
# plugin-verifier: Energy: 93421.4843739821 (57.5%)
# other: Energy: 23886.733312948676 (14.7%)
# test: Energy: 8279.375270276762 (5.1%)
# jar: Energy: 5478.76339982698 (3.4%)
# javadoc: Energy: 5121.020993234899 (3.2%)
# spotless: Energy: 4819.1230120089485 (3.0%)
# compile: Energy: 3370.117706301797 (2.1%)
# resources: Energy: 3285.275331639101 (2.0%)
#
# **** Medium ****
# total: Energy: 2098760.9569307524 (100.0%)
# test: Energy: 498123.8544913868 (23.7%)
# publish: Energy: 253396.32822974655 (12.1%)
# other: Energy: 226978.3755362456 (10.8%)
# func_test: Energy: 220513.28654447265 (10.5%)
# build: Energy: 106061.97106604058 (5.1%)
# compile: Energy: 84167.33540111981 (4.0%)
# checkstyle: Energy: 83140.01414130672 (4.0%)
# test_class: Energy: 77676.74134051621 (3.7%)
# jar: Energy: 67044.2301927741 (3.2%)
# build_src: Energy: 50511.27096261553 (2.4%)
# check: Energy: 49690.72409673771 (2.4%)
#
# **** Large ****
# total: Energy: 4127529.15418646 (100.0%)
# test: Energy: 1351030.9290673598 (32.7%)
# jmh: Energy: 655537.6326827313 (15.9%)
# other: Energy: 376643.1793580127 (9.1%)
# javadoc: Energy: 261636.45524847385 (6.3%)
# build: Energy: 179817.15170316194 (4.4%)
# jar: Energy: 127459.64064210434 (3.1%)
# build_src: Energy: 125407.18865914785 (3.0%)
# compile: Energy: 114938.37691874473 (2.8%)
# integ_test: Energy: 100131.55587452078 (2.4%)
# spotbugs: Energy: 96205.45904621316 (2.3%)
# classes: Energy: 85923.9567857129 (2.1%)
# checkstyle: Energy: 84009.39105371157 (2.0%)

# %%
df = pd.read_csv(overview_dataset)

# Remove Maven Workflows Without Maven Subtasks
df = rq_aux.remove_workflows_no_subtask(df[df[is_build_tool]], prefix, plugins)

df_size = rq_aux.create_dfs_size(df, is_build_tool)
# Out:
# Workflows No Subtask: Removed 306 workflows: 734 -> 428

# %%
# Calculate maven-related energy consumption for all maven projects
tasks = {}

for x in sizes2:
  print(f"*** {x.title()} ***")
  tasks[x] = rq_aux.calc_sum(df_size[x], prefix, plugins)
  rq_aux.calc_workflow_energy_proportion (df_size[x], tasks[x])
  rq_aux.calc_ratio(tasks[x])
  print(f"{df_size[x]['energy'].sum():0.2f}")
# Out:
# *** All ***
# Energy:  6388768 (28.5%)
# Seconds:  295917770296 (26.2%)
# 22451285.32
# *** Small ***
# Energy:  162478 (39.7%)
# Seconds:  7912732769 (36.2%)
# 408979.87
# *** Medium ***
# Energy:  2098761 (36.2%)
# Seconds:  95167688276 (33.5%)
# 5796712.06
# *** Large ***
# Energy:  4127529 (25.4%)
# Seconds:  192837349251 (23.5%)
# 16245593.39
# /Users/sergio/pesquisa/ICT4S_2025/analysis/../scripts/rq_aux.py:46: RuntimeWarning: invalid value encountered in scalar divide
#   return round(100 * x / y, n)

# %%
for x in sizes2:
  print(f"**** {x.title()} ****")
  rq_aux.print_tasks_summary(rq_aux.filter_tasks_by(tasks[x], 'energy', 0.02))
  print("")
# Out:
# **** All ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Gradle_Test ***
# N:  4.7%;  Energy:  29.1%;  Seconds:  26.5%;  Rat_P:  nan%;  Rat_N:  615.5%;
# *** Gradle_Jmh ***
# N:  0.9%;  Energy:  10.4%;  Seconds:  14.9%;  Rat_P:  nan%;  Rat_N:  1152.1%;
# *** Gradle_Other ***
# N:  29.1%;  Energy:  9.8%;  Seconds:  9.5%;  Rat_P:  nan%;  Rat_N:  33.7%;
# *** Gradle_Build ***
# N:  4.6%;  Energy:  4.5%;  Seconds:  4.9%;  Rat_P:  nan%;  Rat_N:  96.8%;
# *** Gradle_Javadoc ***
# N:  3.9%;  Energy:  4.5%;  Seconds:  3.6%;  Rat_P:  nan%;  Rat_N:  115.7%;
# *** Gradle_Publish ***
# N:  0.4%;  Energy:  4.1%;  Seconds:  3.3%;  Rat_P:  nan%;  Rat_N:  908.8%;
# *** Gradle_Func_Test ***
# N:  0.1%;  Energy:  3.8%;  Seconds:  4.0%;  Rat_P:  nan%;  Rat_N:  4272.2%;
# *** Gradle_Compile ***
# N:  5.5%;  Energy:  3.2%;  Seconds:  2.8%;  Rat_P:  nan%;  Rat_N:  57.7%;
# *** Gradle_Jar ***
# N:  7.7%;  Energy:  3.1%;  Seconds:  2.9%;  Rat_P:  nan%;  Rat_N:  40.4%;
# *** Gradle_Build_Src ***
# N:  2.6%;  Energy:  2.8%;  Seconds:  2.6%;  Rat_P:  nan%;  Rat_N:  106.2%;
# *** Gradle_Checkstyle ***
# N:  3.9%;  Energy:  2.6%;  Seconds:  2.3%;  Rat_P:  nan%;  Rat_N:  68.2%;
# *** Gradle_Test_Class ***
# N:  5.2%;  Energy:  2.4%;  Seconds:  2.0%;  Rat_P:  nan%;  Rat_N:  45.5%;
#
# **** Small ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Gradle_Plugin-Verifier ***
# N:  0.7%;  Energy:  57.5%;  Seconds:  56.8%;  Rat_P:  nan%;  Rat_N:  7723.9%;
# *** Gradle_Other ***
# N:  42.2%;  Energy:  14.7%;  Seconds:  13.0%;  Rat_P:  nan%;  Rat_N:  34.9%;
# *** Gradle_Test ***
# N:  4.9%;  Energy:  5.1%;  Seconds:  7.5%;  Rat_P:  nan%;  Rat_N:  104.4%;
# *** Gradle_Jar ***
# N:  7.2%;  Energy:  3.4%;  Seconds:  3.5%;  Rat_P:  nan%;  Rat_N:  46.9%;
# *** Gradle_Javadoc ***
# N:  1.9%;  Energy:  3.2%;  Seconds:  3.7%;  Rat_P:  nan%;  Rat_N:  165.7%;
# *** Gradle_Spotless ***
# N:  6.1%;  Energy:  3.0%;  Seconds:  3.3%;  Rat_P:  nan%;  Rat_N:  48.5%;
# *** Gradle_Compile ***
# N:  3.0%;  Energy:  2.1%;  Seconds:  1.5%;  Rat_P:  nan%;  Rat_N:  69.7%;
# *** Gradle_Resources ***
# N:  2.4%;  Energy:  2.0%;  Seconds:  1.6%;  Rat_P:  nan%;  Rat_N:  84.3%;
#
# **** Medium ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Gradle_Test ***
# N:  5.4%;  Energy:  23.7%;  Seconds:  27.0%;  Rat_P:  nan%;  Rat_N:  437.8%;
# *** Gradle_Publish ***
# N:  0.3%;  Energy:  12.1%;  Seconds:  9.9%;  Rat_P:  nan%;  Rat_N:  4093.4%;
# *** Gradle_Other ***
# N:  17.7%;  Energy:  10.8%;  Seconds:  11.1%;  Rat_P:  nan%;  Rat_N:  61.1%;
# *** Gradle_Func_Test ***
# N:  0.2%;  Energy:  10.5%;  Seconds:  11.0%;  Rat_P:  nan%;  Rat_N:  4947.6%;
# *** Gradle_Build ***
# N:  5.3%;  Energy:  5.1%;  Seconds:  5.7%;  Rat_P:  nan%;  Rat_N:  96.3%;
# *** Gradle_Compile ***
# N:  5.3%;  Energy:  4.0%;  Seconds:  3.7%;  Rat_P:  nan%;  Rat_N:  75.0%;
# *** Gradle_Checkstyle ***
# N:  7.8%;  Energy:  4.0%;  Seconds:  3.0%;  Rat_P:  nan%;  Rat_N:  50.7%;
# *** Gradle_Test_Class ***
# N:  7.5%;  Energy:  3.7%;  Seconds:  3.4%;  Rat_P:  nan%;  Rat_N:  49.2%;
# *** Gradle_Jar ***
# N:  7.5%;  Energy:  3.2%;  Seconds:  2.9%;  Rat_P:  nan%;  Rat_N:  42.9%;
# *** Gradle_Build_Src ***
# N:  2.2%;  Energy:  2.4%;  Seconds:  2.3%;  Rat_P:  nan%;  Rat_N:  107.4%;
# *** Gradle_Check ***
# N:  1.8%;  Energy:  2.4%;  Seconds:  2.6%;  Rat_P:  nan%;  Rat_N:  130.3%;
#
# **** Large ****
# *** Total ***
# N:  100.0%;  Energy:  100.0%;  Seconds:  100.0%;  Rat_P:  nan%;  Rat_N:  100.0%;
# *** Gradle_Test ***
# N:  4.3%;  Energy:  32.7%;  Seconds:  27.0%;  Rat_P:  nan%;  Rat_N:  762.5%;
# *** Gradle_Jmh ***
# N:  1.4%;  Energy:  15.9%;  Seconds:  22.6%;  Rat_P:  nan%;  Rat_N:  1131.7%;
# *** Gradle_Other ***
# N:  35.5%;  Energy:  9.1%;  Seconds:  8.6%;  Rat_P:  nan%;  Rat_N:  25.7%;
# *** Gradle_Javadoc ***
# N:  3.7%;  Energy:  6.3%;  Seconds:  5.1%;  Rat_P:  nan%;  Rat_N:  172.1%;
# *** Gradle_Build ***
# N:  4.4%;  Energy:  4.4%;  Seconds:  4.6%;  Rat_P:  nan%;  Rat_N:  99.1%;
# *** Gradle_Jar ***
# N:  7.9%;  Energy:  3.1%;  Seconds:  2.9%;  Rat_P:  nan%;  Rat_N:  38.9%;
# *** Gradle_Build_Src ***
# N:  2.9%;  Energy:  3.0%;  Seconds:  2.9%;  Rat_P:  nan%;  Rat_N:  103.7%;
# *** Gradle_Compile ***
# N:  5.7%;  Energy:  2.8%;  Seconds:  2.4%;  Rat_P:  nan%;  Rat_N:  48.9%;
# *** Gradle_Integ_Test ***
# N:  0.3%;  Energy:  2.4%;  Seconds:  2.9%;  Rat_P:  nan%;  Rat_N:  759.4%;
# *** Gradle_Spotbugs ***
# N:  1.4%;  Energy:  2.3%;  Seconds:  1.7%;  Rat_P:  nan%;  Rat_N:  168.2%;
# *** Gradle_Classes ***
# N:  6.1%;  Energy:  2.1%;  Seconds:  1.9%;  Rat_P:  nan%;  Rat_N:  34.0%;
# *** Gradle_Checkstyle ***
# N:  1.5%;  Energy:  2.0%;  Seconds:  2.1%;  Rat_P:  nan%;  Rat_N:  135.0%;

# %%
energy_category = {}

for x in sizes2:
  energy_category[x] = rq_aux.calc_energy_category(categories, plugins, 'energy', tasks[x], prefix)

print(energy_category['all'])
print(sum(energy_category['all'].values()))
print(tasks['all']["total"]["energy"], tasks['all'][prefix + "other"]["energy"])
# Out:
# {'Integration Test': 371297.2355633969, 'Unit Test': 1915662.6134352088, 'Compile': 1534869.0303685928, 'Documentation': 314006.4287741668, 'Install': 16951.2923445133, 'Linter': 449295.64988046675, 'Packaging': 579711.7122215633, 'Others': 579465.8260989584, 'Unclassified': 627508.288207208}
# 6388768.076894076
# 6388768.076894074 627508.288207208

# %%
cat_ratios = {}
for key, value in energy_category.items():
    cat_ratios[key] = rq_aux.get_ratio_categories(value)
    
    
results_energy = { }
for x in sizes2:
    results_energy[x] = cat_ratios[x]
    

category_names = []
for key, value in energy_category['all'].items():
    category_names.append(categories_short[key]) 
    #category_names.append(key) 

labels = [re.sub(' ', '\n', x) for x in category_names]
rq_aux.survey(results_energy, labels)
plt.show()

# %%
n_category = {}

for x in sizes2:
  n_category[x] = rq_aux.calc_energy_category(categories, plugins, 'n', tasks[x], prefix)

print(n_category['all'])
print(sum(n_category['all'].values()))
print(tasks['all']["total"]["n"], tasks['all'][prefix + "other"]["n"])
# Out:
# {'Integration Test': 262, 'Unit Test': 2585, 'Compile': 8790, 'Documentation': 1890, 'Install': 114, 'Linter': 4060, 'Packaging': 11579, 'Others': 3333, 'Unclassified': 13409}
# 46022
# 46022 13409

# %%
cat_ratios = {}
for key, value in n_category.items():
    cat_ratios[key] = rq_aux.get_ratio_categories(value)
    
    
results_n = { }
for x in sizes2:
    results_n[x] = cat_ratios[x]
    

category_names = []
for key, value in n_category['all'].items():
    category_names.append(categories_short[key]) 
    #category_names.append(key) 

labels = [re.sub(' ', '\n', x) for x in category_names]
rq_aux.survey(results_n, labels)
plt.show()

# %%
rq_aux.survey_two(results_energy, results_n, labels)

# %%
time_category = {}

for x in sizes2:
  time_category[x] = rq_aux.calc_energy_category(categories, plugins, 'seconds', tasks[x], prefix)

print(time_category['all'])
print(sum(time_category['all'].values()))
print(tasks['all']["total"]["seconds"], tasks['all'][prefix + "other"]["seconds"])
# Out:
# {'Integration Test': 19331294105, 'Unit Test': 81405467659, 'Compile': 82316105139, 'Documentation': 11766262870, 'Install': 1039070294, 'Linter': 18805817977, 'Packaging': 24463565979, 'Others': 28536695717, 'Unclassified': 28253490556}
# 295917770296
# 295917770296 28253490556

# %%
cat_ratios = {}
for key, value in time_category.items():
    cat_ratios[key] = rq_aux.get_ratio_categories(value)
    
    
results = { }
for x in sizes2:
    results[x] = cat_ratios[x]
    

category_names = []
for key, value in time_category['all'].items():
    category_names.append(categories_short[key]) 
    #category_names.append(key) 

labels = [re.sub(' ', '\n', x) for x in category_names]
rq_aux.survey(results, labels)
plt.show()

# %%
df = rq_aux.read_all_tasks(alltasks_dataset, build_tool, noerror)
# Out:
# Tasks With Error: Removed 0 workflows: 183355 -> 183355
# Build tool gradle = 46022

# %%
df_verifier = df[df['kind'] == 'plugin-verifier']

# %%
df_verifier
# Out:
#                                                  file   size build_tool  \
# 9836   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9837   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9838   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9839   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9840   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9841   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9842   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 9843   JetBrains_intellij-sdk-docs___code-samples.yml  small     gradle
# 91275   halirutan_IntelliJ-Key-Promoter-X___build.yml  small     gradle
#
#                   kind        energy     seconds  has_error  error_msg
# 9836   plugin-verifier  21977.011567  1132037337      False        NaN
# 9837   plugin-verifier  20386.443613   910595326      False        NaN
# 9838   plugin-verifier  20229.765034   913548737      False        NaN
# 9839   plugin-verifier  11683.415565   521382122      False        NaN
# 9840   plugin-verifier   9632.792068   459516881      False        NaN
# 9841   plugin-verifier   2844.182497   126348435      False        NaN
# 9842   plugin-verifier   2710.532174   118640997      False        NaN
# 9843   plugin-verifier    740.107061    28500343      False        NaN
# 91275  plugin-verifier   3217.234795   280283399      False        NaN

# %%
len(df_verifier)
# Out:
# 9
